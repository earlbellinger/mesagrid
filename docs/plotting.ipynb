# %% [markdown]
# # Plotting
#
# Visualizing MESA models with mesagrid

# %%
from mesagrid import Track, star_plots
# Out:
# Updated star.py 2025-06-20 14:46:26.561857
# Updated starplots.py 2025-06-20 14:46:27.209789

# %%
track = Track('work/LOGS')

# %% [markdown]
# ## Hertzsprung-Russell Diagram

# %%
star_plots.plot_hr(track, solar_symbol=True)

# %% [markdown]
# ## Internal chemical composition

# %%
star_plots.plot_composition(track, 5) # 5th profile file

# %% [markdown]
# ## Propagation diagram

# %%
star_plots.plot_propagation(track, 5)

# %% [markdown]
# ## Echelle diagram

# %%
star_plots.plot_echelle(track, 5)
# Out:
# Loading Profiles:   0%|          | 0/11 [00:00<?, ?it/s]
# Loading Frequencies:   0%|          | 0/11 [00:00<?, ?it/s]

# %% [markdown]
# ## Interactive plotting

# %%
# need to run this in a jupyter notebook for interactivity to actually work 
star_plots.star_interact(track)
# Out:
# interactive(children=(IntSlider(value=1, description='profile_number', max=11, min=1), Output()), _dom_classes…

# %%
star_plots.plot_structure(track)
# Out:
# Loading GYRE Files:   0%|          | 0/11 [00:00<?, ?it/s]
# C:\Users\mkoro\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\mesagrid\star_plots.py:388: RuntimeWarning: divide by zero encountered in log10
#   Z = np.array([scipy.interpolate.interp1d(g.m/(1.989e33), np.log10(g.N *  10**6/(2*np.pi)),
# interactive(children=(IntSlider(value=1, description='profile_number', max=11, min=1), Output()), _dom_classes…
