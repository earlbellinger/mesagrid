# %%
# %load_ext autoreload
# %autoreload 2

# %%
from star import Track
import star_plots as sp

import os
import numpy as np
import matplotlib.pyplot as plt
import scipy

# %%
test_track = Track(r'C:\Users\mkoro\Research\RR Lyrae\RRLyr (Fall 2024)\rrl_ovf_latest\LOGS_rrl2_step_0.1')
# Out:
# Updated starplots.py 2025-06-16 19:08:24.244236

# %%
sp.plot_composition(test_track, 10, mass=False)
# Out:
# Updated starplots.py 2025-06-16 19:15:48.973304
